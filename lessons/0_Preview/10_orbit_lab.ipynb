# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Orbit Lab

# %% [markdown]
#  acceleration, where the speed increases over time.

# %%
from orbitlib.motion_diagram import motion_diagram

motion_diagram(n_points=6, x0=0, v0=10, a=1, dt=1)

# %%
Hv = 0
x = 0
t = 0
a = 1
v = 0
d_t  = 1

print(f"{'Step':>5} {'Time':>5} {'Pos':>5} {'Vel':>5}")
for i in range(5):
    print(f"{i:5} {t:5.2f} {x:5.2f} {v:5.2f}")
    
    v = v + a * d_t
    x = x + v * d_t
    t = t + d_t

    v = v + a * d_t
    x = x + v * d_t
    t = t + d_t
# Out:
#  Step  Time   Pos   Vel
#     0  0.00  0.00  0.00
#     1  2.00  3.00  2.00
#     2  4.00 10.00  4.00
#     3  6.00 21.00  6.00
#     4  8.00 36.00  8.00

# %% [markdown]
# # Astronomical Data
#
# To get the positions of the planets, we will use [Ecliptic coordinates], wich are relative to the plane of Earths orbit and
# the earths position for the March equinox.
